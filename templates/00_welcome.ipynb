# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/00_welcome.ipynb)
#
# # 🔥 TorchCode — PyTorch Operator Practice
#
# Welcome! This is a JupyterLab-based environment for practicing PyTorch operator implementations.
#
# ## 📁 File Layout
#
# Each problem has **two** notebooks:
#
# | File | Description |
# |------|-------------|
# | `01_relu.ipynb` | ✏️ **Blank template** — write your implementation here |
# | `01_relu_solution.ipynb` | 📖 **Reference solution** — check when you're stuck |
#
# ## How to Use
#
# 1. **Open a problem** — pick a blank template like `01_relu.ipynb`
# 2. **Read the description** — the first cell has the problem statement and signature
# 3. **Write your code** — implement in the `✏️ YOUR IMPLEMENTATION HERE` cell
# 4. **Debug** — insert cells freely for `print(x.shape)` etc.
# 5. **Submit** — run the last cell `check("relu")` to see results
# 6. **Stuck?** — call `hint("relu")` for a nudge, or open the `_solution.ipynb`
# 7. **Reset** — click the 🔄 **Reset** button in the toolbar to restore the blank template and practice again
#
# > 💡 Every notebook also has a **Colab** toolbar button and an **Open in Colab** badge — use them to run problems in Google Colab with zero setup.
#
# ## Quick Start

# %%
from torch_judge import status
status()

# %% [markdown]
# ## Problem List (37 problems)
#
# ### 🧱 Fundamentals — "Implement X from scratch"
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 1 | ReLU | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/01_relu.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/01_relu.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/01_relu_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/01_relu_solution.ipynb) |
# | 2 | Softmax | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/02_softmax.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/02_softmax.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/02_softmax_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/02_softmax_solution.ipynb) |
# | 16 | Cross-Entropy Loss | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/16_cross_entropy.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/16_cross_entropy.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/16_cross_entropy_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/16_cross_entropy_solution.ipynb) |
# | 17 | Dropout | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/17_dropout.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/17_dropout.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/17_dropout_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/17_dropout_solution.ipynb) |
# | 18 | Embedding | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/18_embedding.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/18_embedding.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/18_embedding_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/18_embedding_solution.ipynb) |
# | 19 | GELU | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/19_gelu.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/19_gelu.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/19_gelu_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/19_gelu_solution.ipynb) |
# | 20 | Kaiming Init | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/20_weight_init.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/20_weight_init.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/20_weight_init_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/20_weight_init_solution.ipynb) |
# | 21 | Gradient Clipping | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/21_gradient_clipping.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/21_gradient_clipping.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/21_gradient_clipping_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/21_gradient_clipping_solution.ipynb) |
# | 31 | Gradient Accumulation | 🟢 Easy | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/31_gradient_accumulation.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/31_gradient_accumulation.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/31_gradient_accumulation_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/31_gradient_accumulation_solution.ipynb) |
# | 3 | Linear Layer | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/03_linear.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/03_linear.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/03_linear_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/03_linear_solution.ipynb) |
# | 4 | LayerNorm | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/04_layernorm.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/04_layernorm.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/04_layernorm_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/04_layernorm_solution.ipynb) |
# | 7 | BatchNorm | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/07_batchnorm.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/07_batchnorm.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/07_batchnorm_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/07_batchnorm_solution.ipynb) |
# | 8 | RMSNorm | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/08_rmsnorm.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/08_rmsnorm.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/08_rmsnorm_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/08_rmsnorm_solution.ipynb) |
# | 15 | SwiGLU MLP | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/15_mlp.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/15_mlp.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/15_mlp_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/15_mlp_solution.ipynb) |
# | 22 | Conv2d | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/22_conv2d.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/22_conv2d.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/22_conv2d_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/22_conv2d_solution.ipynb) |
#
# ### 🧠 Attention Mechanisms
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 23 | Cross-Attention | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/23_cross_attention.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/23_cross_attention.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/23_cross_attention_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/23_cross_attention_solution.ipynb) |
# | 5 | Scaled Dot-Product Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/05_attention.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/05_attention.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/05_attention_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/05_attention_solution.ipynb) |
# | 6 | Multi-Head Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/06_multihead_attention.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/06_multihead_attention.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/06_multihead_attention_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/06_multihead_attention_solution.ipynb) |
# | 9 | Causal Self-Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/09_causal_attention.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/09_causal_attention.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/09_causal_attention_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/09_causal_attention_solution.ipynb) |
# | 10 | Grouped Query Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/10_gqa.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/10_gqa.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/10_gqa_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/10_gqa_solution.ipynb) |
# | 11 | Sliding Window Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/11_sliding_window.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/11_sliding_window.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/11_sliding_window_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/11_sliding_window_solution.ipynb) |
# | 12 | Linear Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/12_linear_attention.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/12_linear_attention.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/12_linear_attention_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/12_linear_attention_solution.ipynb) |
# | 14 | KV Cache Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/14_kv_cache.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/14_kv_cache.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/14_kv_cache_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/14_kv_cache_solution.ipynb) |
# | 24 | RoPE | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/24_rope.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/24_rope.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/24_rope_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/24_rope_solution.ipynb) |
# | 25 | Flash Attention | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/25_flash_attention.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/25_flash_attention.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/25_flash_attention_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/25_flash_attention_solution.ipynb) |
#
# ### 🏗️ Architecture & Adaptation
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 26 | LoRA | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/26_lora.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/26_lora.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/26_lora_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/26_lora_solution.ipynb) |
# | 27 | ViT Patch Embedding | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/27_vit_patch.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/27_vit_patch.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/27_vit_patch_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/27_vit_patch_solution.ipynb) |
# | 13 | GPT-2 Block | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/13_gpt2_block.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/13_gpt2_block.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/13_gpt2_block_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/13_gpt2_block_solution.ipynb) |
# | 28 | Mixture of Experts | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/28_moe.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/28_moe.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/28_moe_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/28_moe_solution.ipynb) |
#
# ### ⚙️ Training & Optimization
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 29 | Adam Optimizer | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/29_adam.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/29_adam.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/29_adam_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/29_adam_solution.ipynb) |
# | 30 | Cosine LR Scheduler | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/30_cosine_lr.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/30_cosine_lr.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/30_cosine_lr_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/30_cosine_lr_solution.ipynb) |
#
# ### 🎯 Inference & Decoding
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 32 | Top-k / Top-p Sampling | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/32_topk_sampling.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/32_topk_sampling.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/32_topk_sampling_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/32_topk_sampling_solution.ipynb) |
# | 33 | Beam Search | 🟡 Medium | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/33_beam_search.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/33_beam_search.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/33_beam_search_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/33_beam_search_solution.ipynb) |
# | 34 | Speculative Decoding | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/34_speculative_decoding.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/34_speculative_decoding.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/34_speculative_decoding_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/34_speculative_decoding_solution.ipynb) |
#
# ### 🔬 Advanced
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 35 | BPE Tokenizer | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/35_bpe.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/35_bpe.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/35_bpe_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/35_bpe_solution.ipynb) |
# | 36 | INT8 Quantization | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/36_int8_quantization.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/36_int8_quantization.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/36_int8_quantization_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/36_int8_quantization_solution.ipynb) |
# | 37 | DPO Loss | 🔴 Hard | [GitHub](https://github.com/duoan/TorchCode/blob/master/templates/37_dpo_loss.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/37_dpo_loss.ipynb) | [GitHub](https://github.com/duoan/TorchCode/blob/master/solutions/37_dpo_loss_solution.ipynb) · [Colab](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/37_dpo_loss_solution.ipynb) |
#
# ## Useful Commands
#
# ```python
# from torch_judge import check, hint, status
#
# status()                   # Progress dashboard
# check("relu")              # Judge your implementation
# hint("causal_attention")   # Get a hint
# ```
