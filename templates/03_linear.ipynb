# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/03_linear.ipynb)
#
# # 🟡 Medium: Simple Linear Layer
#
# Implement a fully-connected linear layer: **y = xW^T + b**
#
# ### Signature
# ```python
# class SimpleLinear:
#     def __init__(self, in_features: int, out_features: int): ...
#     def forward(self, x: torch.Tensor) -> torch.Tensor: ...
# ```
#
# ### Requirements
# - `self.weight`: shape `(out_features, in_features)`, init with `randn * (1/√in_features)`
# - `self.bias`: shape `(out_features,)`, init as zeros
# - Both must have `requires_grad=True`
# - `forward(x)` computes `x @ W^T + b`
# - Do **NOT** use `torch.nn.Linear`

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import math
# Out:
# /usr/local/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
# ✏️ YOUR IMPLEMENTATION HERE
class SimpleLinear:
    def __init__(self, in_features: int, out_features: int):
        self.weight = torch.randn((out_features, in_features)) * 1 / torch.sqrt(torch.tensor(in_features))
        # here the operation does not need to be part of the computational graph, so we could use math.sqrt(in_features)
        self.weight.requires_grad_(True)
        self.bias = torch.zeros((out_features), requires_grad=True)
        #  PyTorch automatically treats it as (1, out_features) and broadcasts across the batch dimension

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Compute y = x @ W^T + b
        return x @ self.weight.T + self.bias

# %%
# 🧪 Debug
layer = SimpleLinear(8, 4)
print("W shape:", layer.weight.shape)  # should be (4, 8)
print("b shape:", layer.bias.shape)    # should be (4,)

x = torch.randn(2, 8)
y = layer.forward(x)
print("Output shape:", y.shape)        # should be (2, 4)
# Out:
# W shape: torch.Size([4, 8])
# b shape: torch.Size([4])
# Output shape: torch.Size([2, 4])

# %%
# ✅ SUBMIT
from torch_judge import check
check("linear")
# Out:
# 🧪 Testing: Simple Linear Layer (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Weight & bias shape (0.9ms)
#   ✅ [2/3] Forward pass (0.3ms)
#   ✅ [3/3] Gradient flow (3.8ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (5.1ms total)
#   Progress saved. Run status() to see your dashboard.
